# %%
import requests
import matplotlib.pyplot as plt
import json
import pandas as pd

# %% [markdown]
# ## #1)

# %%
endpoint = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD'

params = {
    'format': 'json',
    'per_page': 17024
}

response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
res = response.json()

# %%
pd.DataFrame(res[1])['indicator'][0]

gdp_ppp = pd.json_normalize(res[1])

# %%
gdp_ppp['indicator.value'].reset_index()
# Out:
#        index                                    indicator.value
# 0          0  GDP per capita, PPP (constant 2021 internation...
# 1          1  GDP per capita, PPP (constant 2021 internation...
# 2          2  GDP per capita, PPP (constant 2021 internation...
# 3          3  GDP per capita, PPP (constant 2021 internation...
# 4          4  GDP per capita, PPP (constant 2021 internation...
# ...      ...                                                ...
# 17019  17019  GDP per capita, PPP (constant 2021 internation...
# 17020  17020  GDP per capita, PPP (constant 2021 internation...
# 17021  17021  GDP per capita, PPP (constant 2021 internation...
# 17022  17022  GDP per capita, PPP (constant 2021 internation...
# 17023  17023  GDP per capita, PPP (constant 2021 internation...
#
# [17024 rows x 2 columns]

# %%
gdp_ppp
# Out:
#       countryiso3code  date        value unit obs_status  decimal  \
# 0                 AFE  2023  4047.007031                        0
# 1                 AFE  2022  4038.638689                        0
# 2                 AFE  2021  3994.171654                        0
# 3                 AFE  2020  3919.499230                        0
# 4                 AFE  2019  4130.057222                        0
# ...               ...   ...          ...  ...        ...      ...
# 17019             ZWE  1964          NaN                        0
# 17020             ZWE  1963          NaN                        0
# 17021             ZWE  1962          NaN                        0
# 17022             ZWE  1961          NaN                        0
# 17023             ZWE  1960          NaN                        0
#
#             indicator.id                                    indicator.value  \
# 0      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# ...

# %%
gdp_ppp.shape
#gdp_ppp['indicator'][]
# Out:
# (17024, 10)

# %% [markdown]
# ## #2)

# %%
endpoint = 'https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN'

params = {
    'format': 'json',
    'per_page': 17024
}

response = requests.get(endpoint, params = params)

# %%
response
# Out:
# <Response [200]>

# %%
res2 = response.json()

# %%
res2[1]
# Out:
# [{'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2023',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2022',
#   'value': 62.8990306485382,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
#    'value': 'Life expectancy at birth, total (years)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 62.4545896453863,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'SP.DYN.LE00.IN',
# ...

# %%
pd.DataFrame(res[1])

LifeExp_TotYears = pd.json_normalize(res[1])

# %%
LifeExp_TotYears
# Out:
#       countryiso3code  date        value unit obs_status  decimal  \
# 0                 AFE  2023  4047.007031                        0
# 1                 AFE  2022  4038.638689                        0
# 2                 AFE  2021  3994.171654                        0
# 3                 AFE  2020  3919.499230                        0
# 4                 AFE  2019  4130.057222                        0
# ...               ...   ...          ...  ...        ...      ...
# 17019             ZWE  1964          NaN                        0
# 17020             ZWE  1963          NaN                        0
# 17021             ZWE  1962          NaN                        0
# 17022             ZWE  1961          NaN                        0
# 17023             ZWE  1960          NaN                        0
#
#             indicator.id                                    indicator.value  \
# 0      NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2021 internation...
# ...

# %% [markdown]
# ## #3)

# %%
gdp_ppp = gdp_ppp.drop(['unit','obs_status'], axis = 1)

# %%
LifeExp_TotYears = LifeExp_TotYears.drop(['unit','obs_status'], axis = 1)

# %%
gdp_merged = gdp_ppp.merge(LifeExp_TotYears)

# %%
gdp_merged.rename(columns = {'value':'GDP_Per_Capita', 'indicator.id':'ind.id', 'indicator.value':'ind.value', 'country.value':'country'}, inplace = True)

# %%
gdp_merged
# Out:
#       countryiso3code  date  GDP_Per_Capita  decimal             ind.id  \
# 0                 AFE  2023     4047.007031        0  NY.GDP.PCAP.PP.KD
# 1                 AFE  2022     4038.638689        0  NY.GDP.PCAP.PP.KD
# 2                 AFE  2021     3994.171654        0  NY.GDP.PCAP.PP.KD
# 3                 AFE  2020     3919.499230        0  NY.GDP.PCAP.PP.KD
# 4                 AFE  2019     4130.057222        0  NY.GDP.PCAP.PP.KD
# ...               ...   ...             ...      ...                ...
# 17019             ZWE  1964             NaN        0  NY.GDP.PCAP.PP.KD
# 17020             ZWE  1963             NaN        0  NY.GDP.PCAP.PP.KD
# 17021             ZWE  1962             NaN        0  NY.GDP.PCAP.PP.KD
# 17022             ZWE  1961             NaN        0  NY.GDP.PCAP.PP.KD
# 17023             ZWE  1960             NaN        0  NY.GDP.PCAP.PP.KD
#
#                                                ind.value country.id  \
# ...
